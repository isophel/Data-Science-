# %%
import pandas
df1 = pandas.DataFrame([[20,13,23],[45,34,67]],columns=["Price","Age","Comment"])
df1
# Out:
#    Price  Age  Comment
# 0     20   13       23
# 1     45   34       67

# %%
dir(df1)
# Out:
# ['Age',
#  'Comment',
#  'Price',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
import pandas
dta = pandas.read_csv("supermarkets.csv")
dta
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dta2 = pandas.read_json("supermarkets.json")
dta2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'pandasdataframe.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas
dta3 =pandas.read_excel("supermarkets.xlsx")
dta3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
import pandas
dta4 = pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
dta4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dta5 = pandas.read_csv("data.txt",sep=";")
dta5
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA       Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA   Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA   Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA    Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA       Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA    Richvalley  20

# %%
dta5.columns = ["ID","Address","City","State","Country","Name","Employees"]
dta5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 1   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 2   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 3   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 4   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0         15
# 1         25
# 2         10
# 3         12
# 4         20

# %%
len(dta5.index)
# Out:
# 5

# %%
dta5["Continent"]= dta5.shape[0]*["NorthAmerica"]
dta5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 1   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 2   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 3   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 4   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees     Continent
# 0         15  NorthAmerica
# 1         25  NorthAmerica
# 2         10  NorthAmerica
# 3         12  NorthAmerica
# 4         20  NorthAmerica

# %%
dta5["Continent"]= dta5["Country"]+ ","+ "NorthAmerica"
dta5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 1   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 2   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 3   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 4   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees         Continent
# 0         15  USA,NorthAmerica
# 1         25  USA,NorthAmerica
# 2         10  USA,NorthAmerica
# 3         12  USA,NorthAmerica
# 4         20  USA,NorthAmerica

# %%
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

nom.geocode("1056 Sanchez St,San Francisco,California")
# Out:
# Location(1056 Sanchez St, San Francisco, California, 94114, (37.75213100377104, -122.43002800384072, 0.0))

# %%
import pandas
from geopy.geocoders import ArcGIS
nom = ArcGIS()
df  = pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df['Address'] = df['Address']+ "," + df['City'] +","+ df['State']
df['Coordinates'] = df['Address'].apply(nom.geocode)
df
# Out:
#    ID                                     Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114  San Francisco
#
#               State Country          Name  Employees  \
# 0          CA 94114     USA       Madeira          8
# 1          CA 94119     USA   Bready Shop         15
# 2  California 94114     USA   Super River         25
# 3          CA 94114     USA    Ben's Shop         10
# 4        California     USA       Sanchez         12
# 5          CA 94114     USA    Richvalley         20
#
#                                          Coordinates
# 0  (3666 21st St, San Francisco, California, 9411...
# ...

# %%
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df['Latitudes'] = df['Coordinates'].apply(lambda X: X.latitude if X!= None else None )
df['Longitudes'] = df['Coordinates'].apply(lambda X: X.longitude if X!= None else None )
df
# Out:
#    ID                                     Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114  San Francisco
#
#               State Country          Name  Employees  \
# 0          CA 94114     USA       Madeira          8
# 1          CA 94119     USA   Bready Shop         15
# 2  California 94114     USA   Super River         25
# 3          CA 94114     USA    Ben's Shop         10
# 4        California     USA       Sanchez         12
# 5          CA 94114     USA    Richvalley         20
#
#                                          Coordinates  Latitudes  Longitudes
# ...
